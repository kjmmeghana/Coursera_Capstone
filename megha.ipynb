# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import json 
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
brooklyn_data = neighborhoods[neighborhoods['Borough'] == 'Brooklyn'].reset_index(drop=True)
brooklyn_data.head()
# Out:
#     Borough Neighborhood   Latitude  Longitude
# 0  Brooklyn    Bay Ridge  40.625801 -74.030621
# 1  Brooklyn  Bensonhurst  40.611009 -73.995180
# 2  Brooklyn  Sunset Park  40.645103 -74.010316
# 3  Brooklyn   Greenpoint  40.730201 -73.954241
# 4  Brooklyn    Gravesend  40.595260 -73.973471

# %%
address = 'Brooklyn, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Brooklyn are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Brooklyn are 40.6501038, -73.9495823.

# %%
# create map of Manhattan using latitude and longitude values
map_brooklyn = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(brooklyn_data['Latitude'], brooklyn_data['Longitude'], brooklyn_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_brooklyn)  
    
map_brooklyn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = '2VFI3ZTFWLKJPSV1DUCE4XBR5IO4KVXVVXKPFKYKEPY5LJUW' # your Foursquare ID
CLIENT_SECRET = 'Z4GWZ4F3HHFBYIZBH0SNI2SJ2HQEU4AADE4G0YWTFSPXYYQZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2VFI3ZTFWLKJPSV1DUCE4XBR5IO4KVXVVXKPFKYKEPY5LJUW
# CLIENT_SECRET:Z4GWZ4F3HHFBYIZBH0SNI2SJ2HQEU4AADE4G0YWTFSPXYYQZ

# %%
import urllib
def getNearbyVenues(names, latitudes, longitudes, radius=50, categoryIds=''):
    try:
        venues_list=[]
        for name, lat, lng in zip(names, latitudes, longitudes):
            #print(name)

            # create the API request URL
            url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)

            if (categoryIds != ''):
                url = url + '&categoryId={}'
                url = url.format(categoryIds)

            # make the GET request
            response = requests.get(url).json()
            results = response["response"]['venues']
            #results = requests.get(url).json()["response"]['venues']
            
            # return only relevant information for each nearby venue
            for v in results:
                success = False
                try:
                    category = v['categories'][0]['name']
                    success = True
                except:
                    pass

                if success:
                    venues_list.append([(
                        name, 
                        lat, 
                        lng, 
                        v['name'], 
                        v['location']['lat'], 
                        v['location']['lng'],
                        v['categories'][0]['name']
                    )])

        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    except:
         pass

    return(nearby_venues)

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 50 # define radius

brooklyn_venues_food = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude'],categoryIds='4d4b7105d754a06374d81259')

# %%
print(brooklyn_venues_food.shape)
brooklyn_venues_food.head()
# Out:
# (210, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Bay Ridge              40.625801              -74.030621
# 1    Bay Ridge              40.625801              -74.030621
# 2    Bay Ridge              40.625801              -74.030621
# 3    Bay Ridge              40.625801              -74.030621
# 4    Bay Ridge              40.625801              -74.030621
#
#                                       Venue  Venue Latitude  Venue Longitude  \
# 0  RED OAK Restaurant & Bar & Hookah Lounge       40.625447       -74.030246
# 1            Georgian Dream Cafe and Bakery       40.625586       -74.030196
# 2                          Spartan Souvlaki       40.625511       -74.030202
# 3                                 Blue Door       40.625208       -74.030353
# 4                            Vela Tapas Bar       40.625463       -74.030161
#
#          Venue Category
# 0            Hookah Bar
# 1  Caucasian Restaurant
# 2      Greek Restaurant
# 3      Greek Restaurant
# 4    Spanish Restaurant

# %%
brooklyn_venues_food.groupby('Neighborhood').count()
# Out:
#                    Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Bath Beach                             4                       4      4
# Bay Ridge                              7                       7      7
# Brighton Beach                         5                       5      5
# Brooklyn Heights                       1                       1      1
# Brownsville                            1                       1      1
# Bushwick                               7                       7      7
# Carroll Gardens                       11                      11     11
# City Line                              3                       3      3
# Clinton Hill                          11                      11     11
# Cobble Hill                            4                       4      4
# Coney Island                           1                       1      1
# Cypress Hills                          3                       3      3
# Downtown                              20                      20     20
# Dumbo                                 16                      16     16
# East Flatbush                          2                       2      2
# East New York                          2                       2      2
# East Williamsburg                      2                       2      2
# Erasmus                                2                       2      2
# Flatlands                              1                       1      1
# Fort Greene                            2                       2      2
# Fulton Ferry                           4                       4      4
# Gowanus                                1                       1      1
# Greenpoint                            15                      15     15
# Homecrest                             12                      12     12
# Kensington                             7                       7      7
# Manhattan Beach                        1                       1      1
# Marine Park                            3                       3      3
# North Side                             6                       6      6
# Ocean Hill                             2                       2      2
# Park Slope                            21                      21     21
# Prospect Heights                       1                       1      1
# South Side                            17                      17     17
# Sunset Park                            6                       6      6
# Vinegar Hill                           2                       2      2
# Weeksville                             4                       4      4
# Windsor Terrace                        2                       2      2
# Wingate                                1                       1      1
#
#                    Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Bath Beach                      4                4               4
# Bay Ridge                       7                7               7
# Brighton Beach                  5                5               5
# Brooklyn Heights                1                1               1
# Brownsville                     1                1               1
# Bushwick                        7                7               7
# Carroll Gardens                11               11              11
# City Line                       3                3               3
# Clinton Hill                   11               11              11
# Cobble Hill                     4                4               4
# Coney Island                    1                1               1
# Cypress Hills                   3                3               3
# Downtown                       20               20              20
# Dumbo                          16               16              16
# East Flatbush                   2                2               2
# East New York                   2                2               2
# East Williamsburg               2                2               2
# Erasmus                         2                2               2
# Flatlands                       1                1               1
# Fort Greene                     2                2               2
# Fulton Ferry                    4                4               4
# Gowanus                         1                1               1
# Greenpoint                     15               15              15
# Homecrest                      12               12              12
# Kensington                      7                7               7
# Manhattan Beach                 1                1               1
# Marine Park                     3                3               3
# North Side                      6                6               6
# Ocean Hill                      2                2               2
# Park Slope                     21               21              21
# Prospect Heights                1                1               1
# South Side                     17               17              17
# Sunset Park                     6                6               6
# Vinegar Hill                    2                2               2
# Weeksville                      4                4               4
# Windsor Terrace                 2                2               2
# Wingate                         1                1               1

# %%
def addToMap(df, color, existingMap):
    for lat, lng, local, venue, venueCat in zip(df['Venue Latitude'], df['Venue Longitude'], df['Neighborhood'], df['Venue'], df['Venue Category']):
        label = '{} ({}) - {}'.format(venue, venueCat, local)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7).add_to(existingMap)

# %%
map_brooklyn_food = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(brooklyn_venues_food, 'red', map_brooklyn_food)
map_brooklyn_food
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 50 # define radius

brooklyn_venues_shop = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude'],categoryIds='4d4b7105d754a06378d81259')

# %%
brooklyn_venues_shop.shape
# Out:
# (294, 7)

# %%
map_brooklyn_shop = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(brooklyn_venues_shop, 'red', map_brooklyn_shop)
map_brooklyn_shop
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 50 # define radius

brooklyn_venues_col = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude'],categoryIds='4d4b7105d754a06372d81259')

# %%
brooklyn_venues_col.shape
# Out:
# (9, 7)

# %%
map_brooklyn_col = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(brooklyn_venues_col, 'red', map_brooklyn_col)
map_brooklyn_col
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def addColumn(startDf, columnTitle, dataDf):
    grouped = dataDf.groupby('Neighborhood').count()
    
    for n in startDf['Neighborhood']:
        try:
            startDf.loc[startDf['Neighborhood'] == n,columnTitle] = grouped.loc[n, 'Venue']
        except:
            startDf.loc[startDf['Neighborhood'] == n,columnTitle] = 0

# %%
brook_data = brooklyn_data.copy()

addColumn(brook_data, 'Food Joints', brooklyn_venues_food)
addColumn(brook_data, 'Shops & Services', brooklyn_venues_shop)
addColumn(brook_data, 'Office', brooklyn_venues_col)
brook_data
# Out:
#      Borough               Neighborhood   Latitude  Longitude  Food Joints  \
# 0   Brooklyn                  Bay Ridge  40.625801 -74.030621          7.0
# 1   Brooklyn                Bensonhurst  40.611009 -73.995180          0.0
# 2   Brooklyn                Sunset Park  40.645103 -74.010316          6.0
# 3   Brooklyn                 Greenpoint  40.730201 -73.954241         15.0
# 4   Brooklyn                  Gravesend  40.595260 -73.973471          0.0
# 5   Brooklyn             Brighton Beach  40.576825 -73.965094          5.0
# 6   Brooklyn             Sheepshead Bay  40.586890 -73.943186          0.0
# 7   Brooklyn          Manhattan Terrace  40.614433 -73.957438          0.0
# 8   Brooklyn                   Flatbush  40.636326 -73.958401          0.0
# 9   Brooklyn              Crown Heights  40.670829 -73.943291          0.0
# 10  Brooklyn              East Flatbush  40.641718 -73.936103          2.0
# 11  Brooklyn                 Kensington  40.642382 -73.980421          7.0
# 12  Brooklyn            Windsor Terrace  40.656946 -73.980073          2.0
# 13  Brooklyn           Prospect Heights  40.676822 -73.964859          1.0
# 14  Brooklyn                Brownsville  40.663950 -73.910235          1.0
# 15  Brooklyn               Williamsburg  40.707144 -73.958115          0.0
# 16  Brooklyn                   Bushwick  40.698116 -73.925258          7.0
# 17  Brooklyn         Bedford Stuyvesant  40.687232 -73.941785          0.0
# 18  Brooklyn           Brooklyn Heights  40.695864 -73.993782          1.0
# 19  Brooklyn                Cobble Hill  40.687920 -73.998561          4.0
# 20  Brooklyn            Carroll Gardens  40.680540 -73.994654         11.0
# 21  Brooklyn                   Red Hook  40.676253 -74.012759          0.0
# 22  Brooklyn                    Gowanus  40.673931 -73.994441          1.0
# 23  Brooklyn                Fort Greene  40.688527 -73.972906          2.0
# 24  Brooklyn                 Park Slope  40.672321 -73.977050         21.0
# 25  Brooklyn              Cypress Hills  40.682391 -73.876616          3.0
# 26  Brooklyn              East New York  40.669926 -73.880699          2.0
# 27  Brooklyn              Starrett City  40.647589 -73.879370          0.0
# 28  Brooklyn                   Canarsie  40.635564 -73.902093          0.0
# 29  Brooklyn                  Flatlands  40.630446 -73.929113          1.0
# 30  Brooklyn                Mill Island  40.606336 -73.908186          0.0
# 31  Brooklyn            Manhattan Beach  40.577914 -73.943537          1.0
# 32  Brooklyn               Coney Island  40.574293 -73.988683          1.0
# 33  Brooklyn                 Bath Beach  40.599519 -73.998752          4.0
# 34  Brooklyn               Borough Park  40.633131 -73.990498          0.0
# 35  Brooklyn              Dyker Heights  40.619219 -74.019314          0.0
# 36  Brooklyn            Gerritsen Beach  40.590848 -73.930102          0.0
# 37  Brooklyn                Marine Park  40.609748 -73.931344          3.0
# 38  Brooklyn               Clinton Hill  40.693229 -73.967843         11.0
# 39  Brooklyn                   Sea Gate  40.576375 -74.007873          0.0
# 40  Brooklyn                   Downtown  40.690844 -73.983463         20.0
# 41  Brooklyn                Boerum Hill  40.685683 -73.983748          0.0
# 42  Brooklyn  Prospect Lefferts Gardens  40.658420 -73.954899          0.0
# 43  Brooklyn                 Ocean Hill  40.678403 -73.913068          2.0
# 44  Brooklyn                  City Line  40.678570 -73.867976          3.0
# 45  Brooklyn               Bergen Beach  40.615150 -73.898556          0.0
# 46  Brooklyn                    Midwood  40.625596 -73.957595          0.0
# 47  Brooklyn        Prospect Park South  40.647009 -73.962613          0.0
# 48  Brooklyn                 Georgetown  40.623845 -73.916075          0.0
# 49  Brooklyn          East Williamsburg  40.708492 -73.938858          2.0
# 50  Brooklyn                 North Side  40.714823 -73.958809          6.0
# 51  Brooklyn                 South Side  40.710861 -73.958001         17.0
# 52  Brooklyn              Ocean Parkway  40.613060 -73.968367          0.0
# 53  Brooklyn              Fort Hamilton  40.614768 -74.031979          0.0
# 54  Brooklyn                Ditmas Park  40.643675 -73.961013          0.0
# 55  Brooklyn                    Wingate  40.660947 -73.937187          1.0
# 56  Brooklyn                      Rugby  40.655572 -73.926882          0.0
# 57  Brooklyn             Remsen Village  40.652117 -73.916653          0.0
# 58  Brooklyn                   New Lots  40.662744 -73.885118          0.0
# 59  Brooklyn            Paerdegat Basin  40.631318 -73.902335          0.0
# 60  Brooklyn                 Mill Basin  40.615974 -73.915154          0.0
# 61  Brooklyn               Fulton Ferry  40.703281 -73.995508          4.0
# 62  Brooklyn               Vinegar Hill  40.703321 -73.981116          2.0
# 63  Brooklyn                 Weeksville  40.675040 -73.930531          4.0
# 64  Brooklyn          Broadway Junction  40.677861 -73.903317          0.0
# 65  Brooklyn                      Dumbo  40.703176 -73.988753         16.0
# 66  Brooklyn                  Homecrest  40.598525 -73.959185         12.0
# 67  Brooklyn              Highland Park  40.681999 -73.890346          0.0
# 68  Brooklyn                    Madison  40.609378 -73.948415          0.0
# 69  Brooklyn                    Erasmus  40.646926 -73.948177          2.0
#
#     Shops & Services  Office
# 0               10.0     0.0
# 1                0.0     0.0
# 2               12.0     0.0
# 3               25.0     0.0
# 4                1.0     0.0
# 5               15.0     0.0
# 6                0.0     0.0
# 7                1.0     0.0
# 8                0.0     0.0
# 9                2.0     0.0
# 10               8.0     0.0
# 11               6.0     0.0
# 12               2.0     0.0
# 13               1.0     2.0
# 14               0.0     0.0
# 15               0.0     0.0
# 16               5.0     0.0
# 17               7.0     0.0
# 18               1.0     0.0
# 19               1.0     0.0
# 20              12.0     1.0
# 21               0.0     0.0
# 22               2.0     0.0
# 23               1.0     1.0
# 24              39.0     0.0
# 25               2.0     0.0
# 26               0.0     0.0
# 27               1.0     0.0
# 28               0.0     0.0
# 29               4.0     0.0
# 30               0.0     0.0
# 31               0.0     0.0
# 32               0.0     1.0
# 33               4.0     0.0
# 34               0.0     0.0
# 35               0.0     0.0
# 36               0.0     0.0
# 37              11.0     0.0
# 38              16.0     0.0
# 39               0.0     0.0
# 40              14.0     0.0
# 41               1.0     0.0
# 42               0.0     0.0
# 43               1.0     0.0
# 44              11.0     0.0
# 45               0.0     0.0
# 46               0.0     0.0
# 47               1.0     0.0
# 48               0.0     0.0
# 49               0.0     0.0
# 50               7.0     0.0
# 51              23.0     0.0
# 52               1.0     0.0
# 53               1.0     1.0
# 54               1.0     1.0
# 55               0.0     0.0
# 56               2.0     0.0
# 57               0.0     0.0
# 58               1.0     0.0
# 59               0.0     0.0
# 60               0.0     0.0
# 61               1.0     0.0
# 62               1.0     0.0
# 63               0.0     0.0
# 64               1.0     0.0
# 65              18.0     1.0
# 66              18.0     0.0
# 67               1.0     0.0
# 68               1.0     1.0
# 69               0.0     0.0

# %%
# negative weight, because Abeledata Restaurant and thus wants to avoid concurrence as much as possible
weight_food = -1

# positive weight, because shop owners and workers are good customers
weight_shop = 1

# positive weight because employees are even better customers
weight_office = 2

# %%
brook_weight = brook_data[['Neighborhood']].copy()

# %%
brook_weight['Score'] = brook_data['Food Joints'] * weight_food + brook_data['Shops & Services'] * weight_shop + brook_data['Office'] * weight_office
brook_weight = brook_weight.sort_values(by=['Score'], ascending=False)
brook_weight
# Out:
#                  Neighborhood  Score
# 24                 Park Slope   18.0
# 3                  Greenpoint   10.0
# 5              Brighton Beach   10.0
# 44                  City Line    8.0
# 37                Marine Park    8.0
# 17         Bedford Stuyvesant    7.0
# 66                  Homecrest    6.0
# 10              East Flatbush    6.0
# 51                 South Side    6.0
# 2                 Sunset Park    6.0
# 38               Clinton Hill    5.0
# 65                      Dumbo    4.0
# 13           Prospect Heights    4.0
# 29                  Flatlands    3.0
# 53              Fort Hamilton    3.0
# 54                Ditmas Park    3.0
# 0                   Bay Ridge    3.0
# 20            Carroll Gardens    3.0
# 68                    Madison    3.0
# 9               Crown Heights    2.0
# 56                      Rugby    2.0
# 52              Ocean Parkway    1.0
# 4                   Gravesend    1.0
# 7           Manhattan Terrace    1.0
# 47        Prospect Park South    1.0
# 32               Coney Island    1.0
# 50                 North Side    1.0
# 67              Highland Park    1.0
# 58                   New Lots    1.0
# 27              Starrett City    1.0
# 64          Broadway Junction    1.0
# 23                Fort Greene    1.0
# 22                    Gowanus    1.0
# 41                Boerum Hill    1.0
# 57             Remsen Village    0.0
# 60                 Mill Basin    0.0
# 48                 Georgetown    0.0
# 59            Paerdegat Basin    0.0
# 46                    Midwood    0.0
# 45               Bergen Beach    0.0
# 42  Prospect Lefferts Gardens    0.0
# 35              Dyker Heights    0.0
# 21                   Red Hook    0.0
# 6              Sheepshead Bay    0.0
# 15               Williamsburg    0.0
# 12            Windsor Terrace    0.0
# 18           Brooklyn Heights    0.0
# 8                    Flatbush    0.0
# 30                Mill Island    0.0
# 28                   Canarsie    0.0
# 33                 Bath Beach    0.0
# 34               Borough Park    0.0
# 1                 Bensonhurst    0.0
# 36            Gerritsen Beach    0.0
# 39                   Sea Gate    0.0
# 31            Manhattan Beach   -1.0
# 62               Vinegar Hill   -1.0
# 25              Cypress Hills   -1.0
# 55                    Wingate   -1.0
# 43                 Ocean Hill   -1.0
# 11                 Kensington   -1.0
# 14                Brownsville   -1.0
# 69                    Erasmus   -2.0
# 16                   Bushwick   -2.0
# 26              East New York   -2.0
# 49          East Williamsburg   -2.0
# 61               Fulton Ferry   -3.0
# 19                Cobble Hill   -3.0
# 63                 Weeksville   -4.0
# 40                   Downtown   -6.0

# %%
map_brook_result = folium.Map(location=[latitude, longitude], zoom_start=14)

brook_winner = brooklyn_data[brooklyn_data['Neighborhood'] == 'Midtown']

for lat, lng, local in zip( brook_winner['Latitude'], brook_winner['Longitude'], brook_winner['Neighborhood']):
    label = '{}'.format(local)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_brook_result) 

addToMap(brooklyn_venues_food[brooklyn_venues_food['Neighborhood'] == 'Midtown'], 'red', map_brook_result)
addToMap(brooklyn_venues_shop[brooklyn_venues_shop['Neighborhood'] == 'Midtown'], 'green', map_brook_result)
addToMap(brooklyn_venues_col[brooklyn_venues_col['Neighborhood'] == 'Midtown'], 'gold', map_brook_result)

map_brook_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
